# %%
from  glob import glob
from time import sleep
from baselines.bench import load_results
from matplotlib import pylab as plt
import numpy as np
import argparse
import os
import pandas as pd


def get_data(my_dir):
    num_good_traj = 0
    
    exps = glob(my_dir+'*')
    d = exps[0]
    df = load_results(d)
    #df = pd.DataFrame() 

    df['f']= df['l'].cumsum()/1000000

    df['perf']= df['r']
    df['perf'].where(df['perf']>0,0,inplace=True)
    df['goal'] = df['perf']>0.9  #guess a threadshold

    return df

fig = plt.figure(clear=True, figsize=(15,9))
ax = plt.subplot(2, 2, 1)

roll = 1000


# ppo +d rho = 0.3
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppod_51'
ppod_1_03 = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppod_52'
ppod_2_03 = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppod_53'
ppod_3_03 = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppod_54'
ppod_4_03 = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppod_55'
ppod_5_03 = get_data(my_dir)


# ppo +d rho = 0.1
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppod_5'
ppod_1_01 = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppod_56'
ppod_2_01 = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppod_57'
ppod_3_01 = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppod_58'
ppod_4_01 = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppod_59'
ppod_5_01 = get_data(my_dir)

# vanilla ppo
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppod_42'
ppo_1 = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppod_44'
ppo_2 = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppod_45'
ppo_3 = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppod_46'
ppo_4 = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppod_47'
ppo_5 = get_data(my_dir)

# # PPO+bc rho 0.3 50
# my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppobc_1'
# ppobc_1 = get_data(my_dir)
# my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppobc_2'
# ppobc_2 = get_data(my_dir)
# my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppobc_3'
# ppobc_3 = get_data(my_dir)
# my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppobc_4'
# ppobc_4 = get_data(my_dir)

# ppo+bc 50 0.3
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppobc_2'
ppobc_2 = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppobc_10' # useless
ppobc_10 = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppobc_11'
ppobc_11 = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppobc_12'
ppobc_12 = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppobc_13'
ppobc_13 = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppobc_14'
ppobc_14 = get_data(my_dir)

# ppo+bc buffer 0 0.3
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppobc_15'
ppobc_15 = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppobc_16'
ppobc_16 = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppobc_17'
ppobc_17 = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppobc_3'
ppobc_3 = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_ppobc_4'
ppobc_4 = get_data(my_dir)


ppo_1[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax, color = 'orange')
ppo_2[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax ,color = 'orange')
ppo_3[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax ,color = 'orange')
ppo_4[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax ,color = 'orange')
ppo_5[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax ,color = 'orange')


ppod_1_03[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax, color = 'blue')
ppod_2_03[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax ,color = 'blue')
ppod_3_03[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax ,color = 'blue')
ppod_4_03[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax ,color = 'blue')
ppod_5_03[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax ,color = 'blue')

ppobc_2[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax ,color = 'red')
#ppobc_10[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax ,color = 'red')
ppobc_11[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax ,color = 'red')
ppobc_12[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax ,color = 'red')
ppobc_13[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax ,color = 'red')
ppobc_14[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax ,color = 'red')


ppobc_15[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax ,color = 'green')
ppobc_16[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax ,color = 'green')
ppobc_17[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax ,color = 'green')
ppobc_3[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax ,color = 'green')
ppobc_4[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax ,color = 'green')
ax.set_xlabel('N. steps (M)')
ax.set_ylabel('Reward')
plt.xlim((0, 60))
ax.grid(True)
#ax.legend(loc=4, prop={'size': 10})#
ax.legend(bbox_to_anchor=(1.1, 0.6))
# Out:
# /shared/gabriele/miniconda/envs/animal/lib/python3.6/site-packages/baselines/bench/monitor.py:161: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.headers = headers # HACK to preserve backwards compatibility
# /shared/gabriele/miniconda/envs/animal/lib/python3.6/site-packages/IPython/core/events.py:88: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)

# %%
# vanilla ppo
my_dir = '/workspace8/gabriele/RUNS/exp_lunar_ppod_105'
ppo_1_ll = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_lunar_ppod_106'
ppo_2_ll = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_lunar_ppod_107'
ppo_3_ll = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_lunar_ppod_108'
ppo_4_ll = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_lunar_ppod_109'
ppo_5_ll = get_data(my_dir)

# ppo+d rho 0.1
my_dir = '/workspace8/gabriele/RUNS/exp_lunar_ppod_99'
ppod_1_ll = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_lunar_ppod_100'
ppod_2_ll = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_lunar_ppod_101'
ppod_3_ll = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_lunar_ppod_102'
ppod_4_ll = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_lunar_ppod_103'
ppod_5_ll = get_data(my_dir)


# ppobc buffer 50  rho 0.1
my_dir = '/workspace8/gabriele/RUNS/exp_lunar_ppobc_7'
ppobc_1_50_ll = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_lunar_ppobc_8'
ppobc_2_50_ll = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_lunar_ppobc_5'
ppobc_3_50_ll = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_lunar_ppobc_6'
ppobc_4_50_ll = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_lunar_ppobc_81'
ppobc_5_50_ll =  get_data(my_dir) 

# ppobc buffer 0 rho 0.1
my_dir = '/workspace8/gabriele/RUNS/exp_lunar_ppobc_9'
ppobc_1_0_ll = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_lunar_ppobc_10'
ppobc_2_0_ll = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_lunar_ppobc_11'
ppobc_3_0_ll = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_lunar_ppobc_12'
ppobc_4_0_ll = get_data(my_dir)
my_dir = '/workspace8/gabriele/RUNS/exp_lunar_ppobc_13'
ppobc_5_0_ll = get_data(my_dir)



fig = plt.figure(clear=True, figsize=(15,9))
ax = plt.subplot(2, 2, 1)
#ax.set_title(' {} total time: {:.1f} h FPS {:.1f}'.format('PPO+D REACHER',total_time/3600, total_steps/total_time))

ppo_1_ll[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax, color = 'yellow')
ppo_2_ll[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax,  color = 'yellow')
ppo_3_ll[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',   ax=ax, color = 'yellow')
ppo_4_ll[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax,  color = 'yellow')
ppo_5_ll[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',   ax=ax, color = 'yellow')

ppod_1_ll[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax,color = 'green')
ppod_2_ll[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax ,color = 'green')
ppod_3_ll[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',   ax=ax ,color = 'green')
ppod_4_ll[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax,color = 'green')
ppod_5_ll[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax,color = 'green')


ppobc_1_50_ll[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax,color = 'blue')
ppobc_2_50_ll[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax ,color = 'blue')
ppobc_3_50_ll[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',   ax=ax ,color = 'blue')
ppobc_4_50_ll[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax,color = 'blue')
ppobc_5_50_ll[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax,color = 'blue')

ppobc_1_0_ll[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax,color = 'red')
ppobc_2_0_ll[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax ,color = 'red')
ppobc_3_0_ll[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',   ax=ax ,color = 'red')
ppobc_4_0_ll[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax,color = 'red')
ppobc_5_0_ll[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax,color = 'red')

ax.set_xlabel('N. steps (M)')
ax.set_ylabel('Reward')
#plt.xlim((0, 20))
ax.grid(True)
#ax.legend(loc=4, prop={'size': 10})#
ax.legend(bbox_to_anchor=(1.1, 0.6))

# %%
print(ppo_1_ll['f'])
print(ppo_2_ll['f'])
print(ppo_3_ll['f'])
print(ppo_4_ll['f'])
print(ppo_5_ll['f'])


print(ppod_1_ll['f'])
print(ppod_2_ll['f'])
print(ppod_3_ll['f'])
print(ppod_4_ll['f'])
print(ppod_5_ll['f'])

print(ppobc_1_0_ll['f'])
print(ppobc_2_0_ll['f'])
print(ppobc_3_0_ll['f'])
print(ppobc_4_0_ll['f'])
print(ppobc_5_0_ll['f'])

print(ppobc_1_50_ll['f'])
print(ppobc_2_50_ll['f'])
print(ppobc_3_50_ll['f'])
print(ppobc_4_50_ll['f'])
print(ppobc_5_50_ll['f'])
# Out:
# 0          0.000063
# 1          0.000134
# 2          0.000210
# 3          0.000289
# 4          0.000370
#             ...
# 379431    59.988239
# 379432    59.988337
# 379433    59.988548
# 379434    59.988683
# 379435    59.988900
# Name: f, Length: 379436, dtype: float64
# 0          0.000065
# 1          0.000130
# 2          0.000204
# 3          0.000283
# 4          0.000366
#             ...
# 654408    59.989094
# 654409    59.989187
# 654410    59.989267
# 654411    59.989343
# 654412    59.989444
# Name: f, Length: 654413, dtype: float64
# 0          0.000063
# 1          0.000127
# 2          0.000197
# 3          0.000268
# 4          0.000350
#             ...
# 369145    59.988351
# 369146    59.988499
# 369147    59.988629
# 369148    59.988818
# 369149    59.988950
# Name: f, Length: 369150, dtype: float64
# 0          0.000060
# 1          0.000122
# 2          0.000186
# 3          0.000267
# 4          0.000354
#             ...
# 608237    59.988825
# ...

# %%
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_bc_7_test'
bc_data = get_data(my_dir)
fig = plt.figure(clear=True, figsize=(15,9))
ax = plt.subplot(2, 2, 1)
#ax.set_title(' {} total time: {:.1f} h FPS {:.1f}'.format('PPO+D REACHER',total_time/3600, total_steps/total_time))

bc_data[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax, color = 'yellow')
ax.set_xlabel('N. steps (M)')
ax.set_ylabel('Reward')
#plt.xlim((0, 20))
ax.grid(True)
#ax.legend(loc=4, prop={'size': 10})#
ax.legend(bbox_to_anchor=(1.1, 0.6))

# %%
my_dir = '/workspace8/gabriele/RUNS/exp_reacher_bc_3_test'
bc_data = get_data(my_dir)
fig = plt.figure(clear=True, figsize=(15,9))
ax = plt.subplot(2, 2, 1)
#ax.set_title(' {} total time: {:.1f} h FPS {:.1f}'.format('PPO+D REACHER',total_time/3600, total_steps/total_time))

bc_data[['f','reward_woD']].rolling(roll).mean().iloc[0:-1:40].plot('f','reward_woD',  ax=ax, color = 'yellow')
ax.set_xlabel('N. steps (M)')
ax.set_ylabel('Reward')
#plt.xlim((0, 20))
ax.grid(True)
#ax.legend(loc=4, prop={'size': 10})#
ax.legend(bbox_to_anchor=(1.1, 0.6))
